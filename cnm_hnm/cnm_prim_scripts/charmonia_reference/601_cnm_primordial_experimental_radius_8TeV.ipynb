# %% [markdown]
# # CNM (+/- Nucl Abs) x Primordial (Radius) + Experimental\n
# \n
# LHC pPb 8.16 TeV, state-by-state (default: `jpsi_1S`, `psi_2S`).\n
# This notebook calls the verified Python runner:\n
# `cnm_primordial_notebooks/601_cnm_primordial_experimental_radius_8TeV.py`.

# %%
# !conda run -n research python 601_cnm_primordial_experimental_radius_8TeV.py --formation radius --states jpsi_1S,psi_2S --observables cent,y,pt --save-csv --save-pdf
# Out:
# [step 1] building primordial products...
# [step 2] computing CNM for jpsi_1S ...
# [step 2] computing CNM for psi_2S ...
# [done] outputs in: /home/sawin/Desktop/Charmonia/charmonia_combined_analysis/outputs/combined_cnm_primordial_experimental/LHC_8p16TeV/radius

# %%
from pathlib import Path
out = Path('../outputs/combined_cnm_primordial_experimental/LHC_8p16TeV/radius')
print('Output root:', out.resolve())
for p in sorted(out.glob('*.pdf'))[:10]:
    print('-', p.name)
# Out:
# Output root: /home/sawin/Desktop/Charmonia/charmonia_combined_analysis/outputs/combined_cnm_primordial_experimental/LHC_8p16TeV/radius
# - combined_RpA_vs_cent_jpsi_1S_8p16TeV_radius.pdf
# - combined_RpA_vs_cent_psi_2S_8p16TeV_radius.pdf
# - combined_RpA_vs_pT_jpsi_1S_backward_8p16TeV_radius.pdf
# - combined_RpA_vs_pT_jpsi_1S_central_8p16TeV_radius.pdf
# - combined_RpA_vs_pT_jpsi_1S_forward_8p16TeV_radius.pdf
# - combined_RpA_vs_pT_psi_2S_backward_8p16TeV_radius.pdf
# - combined_RpA_vs_pT_psi_2S_central_8p16TeV_radius.pdf
# - combined_RpA_vs_pT_psi_2S_forward_8p16TeV_radius.pdf
# - combined_RpA_vs_y_jpsi_1S_8p16TeV_radius.pdf
# - combined_RpA_vs_y_psi_2S_8p16TeV_radius.pdf
